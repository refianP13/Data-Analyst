# %% [markdown]
# <a href="https://colab.research.google.com/github/refianP13/Data-Analyst/blob/main/Copy_of_DQLab_Query_SELECT%2C_LIMIT_%26_ORDER_BY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><span style='color:#0B2F9F'>Pengantar</span></b>
#
# Dalam analisis data, langkah awal yang penting adalah mengambil, membatasi, dan mengurutkan informasi dari sumber data agar hasil yang diperoleh relevan dan mudah dipahami. Kemampuan untuk menampilkan data sesuai kebutuhan, hanya pada bagian yang diperlukan, serta menyusunnya dengan urutan yang tepat, menjadi dasar dalam proses eksplorasi dan pengolahan data. Dengan pemahaman konsep ini, seorang analis dapat bekerja lebih efisien dalam menemukan pola, menjawab pertanyaan bisnis, dan menyajikan insight yang akurat.

# %% [markdown]
# # <b><span style='color:#0B2F9F'>Latar Belakang</span></b>
#
# Di sebuah sudut kota Jakarta, telah didirikan sebuah restoran pizza bernama DQPizza. Selama satu tahun terakhir, telah dilakukan pencatatan atas setiap transaksi yang terjadi. Mulai dari pemesanan menu hingga pembayaran pelanggan.
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/DQLab%20-%20DQPizza%20Resto%20(1).png" width="30%">
#
# Banyak data telah dikumpulkan dan dicatat. Namun, belum dilakukan pemanfaatan optimal terhadap informasi yang tersedia. Pemilik restoran menginginkan agar data ini dapat dianalisis guna menemukan ruang untuk perbaikan dan melakukan efisiensi operasional sehingga diharapkan dapat meningkatkan penjualan pizza, menekan biaya operasional dan meningkatkan *customer experience*

# %% [markdown]
# # <b><span style='color:#0B2F9F'>Set up</span></b>
#
# Dibutuhkan proses autentikasi dari Google Colab ke Google Big Query. Ikuti langkah berikut https://drive.google.com/file/d/1gW8alZ_PrvcrsieqWCHOR4ssLI_25BRc/view untuk detail step-by-step nya

# %%
# Import library yang dibutuhkan
from google.colab import auth, data_table
from google.cloud import bigquery
from pandas_gbq import to_gbq

# Proses autentikasi akun
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# Buat BigQuery client
project_id = 'dqlabs-project'
client = bigquery.Client(project = project_id)

# %% [markdown]
# <a id="A"></a>
# # <b>A. <span style='color:#0B2F9F'><code>SELECT</code></span></b>
#
# Perintah `SELECT` bertujuan untuk mengambil dan menampilkan data dari tabel di database. Ini penting untuk analisis karena saat menganalisa data perlu mengakses data yang relevan untuk dianalisis seperti mengidentifikasi pola, tren, dan informasi penting lainnya.

# %% [markdown]
# <a id="A.1."></a>
# ## <b>A.1. <span style='color:#0B2F9F'>Menampilkan Semua Data pada Satu Tabel</span></b>
#
# Untuk dapat menampilkan semua isi (data) pada sebuah tabel, eksekusi perintah
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Select1.png" width="50%">
#
# Dalam perintah `SELECT`, tanda bintang (*) digunakan untuk memilih semua kolom dari tabel yang disebutkan. Cara ini merupakan cara cepat untuk mengambil seluruh data tanpa perlu menyebutkan nama-nama kolom satu per satu.
#
# <i>docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/selecting-all.html">https://dev.mysql.com/doc/refman/8.4/en/selecting-all.html</a></i>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Management ingin mengetahui seluruh data transaksi pada DQPizza, sehingga tampilkan semua data pada tabel transaction_order!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua data pada tabel transaction_order
# SELECT * FROM dqlabs-project.dqpizza.transaction_order
# Out:
# Executing query with job ID: 7550b2ab-a0eb-4753-88a5-e3703c25c021
# Query executing: 1.28s
# Job ID 7550b2ab-a0eb-4753-88a5-e3703c25c021 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#         order_id customer_id order_maker_id  order_date order_time  \
# 0      TRX000026  CUST006333      EMP000208  01/01/2025   14:54:26
# 1      TRX000037  CUST003319      EMP000208  01/01/2025   16:56:09
# 2      TRX000057  CUST008422      EMP000208  01/01/2025   19:10:51
# 3      TRX000077  CUST001979      EMP000208  01/02/2025   12:22:46
# 4      TRX000087  CUST004837      EMP000208  01/02/2025   14:01:02
# ...          ...         ...            ...         ...        ...
# 21345  TRX009714  CUST004609      EMP000756  06/12/2025   15:32:54
# 21346  TRX011127  CUST003549      EMP000756  07/05/2025   12:49:09
# 21347  TRX011178  CUST008535      EMP000756  07/06/2025   13:09:22
# 21348  TRX012098  CUST001979      EMP000756  07/21/2025   18:11:15
# 21349  TRX019645  CUST001120      EMP000756  11/30/2025   17:07:35
#
#       completion_time  is_complain   complain_detail         created_date
# 0            15:23:02            0              None  2025-01-01 14:54:31
# 1            17:18:48            0              None  2025-01-01 16:56:14
# 2            19:30:38            0              None  2025-01-01 19:10:56
# 3            12:41:29            0              None  2025-01-02 12:22:51
# 4            14:29:46            0              None  2025-01-02 14:01:07
# ...               ...          ...               ...                  ...
# 21345        15:52:27            1  Wrong pizza size  2025-06-12 15:32:59
# 21346        13:03:28            1  Wrong pizza size  2025-07-05 12:49:14
# 21347        13:28:47            1  Wrong pizza size  2025-07-06 13:09:27
# 21348        18:33:56            1  Wrong pizza size  2025-07-21 18:11:20
# 21349        17:34:36            1  Wrong pizza size  2025-11-30 17:07:40
#
# [21350 rows x 9 columns]

# %% [markdown]
# <a id="A.2."></a>
# ## <b>A.2. <span style='color:#0B2F9F'>Menampilkan Kolom Tertentu pada Satu Tabel</span></b>
#
# Untuk dapat menampilkan isi data pada kolom tertentu pada sebuah tabel, eksekusi perintah
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Select2.png" width="50%">
#
# Gunakan tanda koma untuk mendaftarkan nama kolom yang ingin ditampilkan. Kolom yang disebutkan pertama kali akan ditampilkan paling kiri begitu juga dengan kolom kedua hingga kolom terakhir.
#
# <i>docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/selecting-columns.html">https://dev.mysql.com/doc/refman/8.4/en/selecting-columns.html</a></i>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan kolom order_id, customer_id dan order_date pada tabel transaction_order!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan kolom order_id, customer_id dan order_date pada tabel transaction_order
# Select order_id, customer_id, order_date
# FROM dqlabs-project.dqpizza.transaction_order
# Out:
# Executing query with job ID: 445b3c81-bd34-49d2-9c1d-85ccfa37f5bb
# Query executing: 1.54s
# Job ID 445b3c81-bd34-49d2-9c1d-85ccfa37f5bb successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#         order_id customer_id  order_date
# 0      TRX000208  CUST009755  01/04/2025
# 1      TRX000218  CUST008987  01/04/2025
# 2      TRX000387  CUST004307  01/07/2025
# 3      TRX000403  CUST002835  01/07/2025
# 4      TRX000502  CUST003147  01/08/2025
# ...          ...         ...         ...
# 21345  TRX009812  CUST009740  06/13/2025
# 21346  TRX020835  CUST009740  12/20/2025
# 21347  TRX014036  CUST009740  08/22/2025
# 21348  TRX005932  CUST009740  04/10/2025
# 21349  TRX020194  CUST009740  12/09/2025
#
# [21350 rows x 3 columns]

# %% [markdown]
# <a id="A.3."></a>
# ## <b>A.3. <span style='color:#0B2F9F'>Mengubah Penyebutan Nama Kolom pada Satu Tabel</span></b>
#
# Terkadang perlu untuk memberi nama lain pada saat data ditampilkan untuk mempermudah pembacaan atau tujuan lainnya. Untuk mengubah nama sementara yang diberikan kepada kolom atau tabel dalam query bisa menggunakan perintah `AS` atau biasa disebut Alias. Untuk dapat mengubah nama kolom sementara pada sebuah tabel, eksekusi perintah
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Select3.png" width="50%">

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan kolom order_id, customer_id, order_date dan is_complain pada tabel transaction_order namun ubah penamaan is_complain pada output menjadi is_customer_complain agar lebih jelas</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan kolom order_id, customer_id, order_date dan is_complain pada tabel transaction_order
# -- namun ubah penamaan is_complain pada output menjadi is_customer_complain
# select order_id, customer_id, order_date, is_complain as is_customer_complain
# from dqlabs-project.dqpizza.transaction_order
# Out:
# Executing query with job ID: 5b5f8052-6a13-42bd-a2e0-59d13152dc18
# Query executing: 1.63s
# Job ID 5b5f8052-6a13-42bd-a2e0-59d13152dc18 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#         order_id customer_id  order_date  is_customer_complain
# 0      TRX000026  CUST006333  01/01/2025                     0
# 1      TRX000037  CUST003319  01/01/2025                     0
# 2      TRX000057  CUST008422  01/01/2025                     0
# 3      TRX000077  CUST001979  01/02/2025                     0
# 4      TRX000087  CUST004837  01/02/2025                     0
# ...          ...         ...         ...                   ...
# 21345  TRX009714  CUST004609  06/12/2025                     1
# 21346  TRX011127  CUST003549  07/05/2025                     1
# 21347  TRX011178  CUST008535  07/06/2025                     1
# 21348  TRX012098  CUST001979  07/21/2025                     1
# 21349  TRX019645  CUST001120  11/30/2025                     1
#
# [21350 rows x 4 columns]

# %% [markdown]
# <a id="B"></a>
# # <b>B. <span style='color:#E1B12D'><code>DISTINCT</code></span></b>
#
# Perintah `DISTINCT` dalam SQL digunakan untuk menghapus duplikasi dalam hasil query. Dengan `DISTINCT`, dapat dipastikan bahwa setiap baris dalam hasil query unik dan tidak ada baris yang sama. Untuk menggunakan perintah ini haruslah diletakkan setelah perintah `SELECT`.
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Distinct.png" width="50%">
#
# docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/distinct-optimization.html"><i>https://dev.mysql.com/doc/refman/8.4/en/distinct-optimization.html</a></i>

# %% [markdown]
# <a id="B.1."></a>
# ## <b>B.1. <span style='color:#0B2F9F'>Nilai Unik pada Satu Kolom Tertentu</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Beberapa kali DQPizza mengalami komplain, sebutkan apa saja komplain yang pernah terjadi di DQPizza!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan komplain apa saja yang pernah terjadi di DQPizza
# SELECT DISTINCT complain_detail FROM dqlabs-project.dqpizza.transaction_order WHERE complain_detail IS NOT NULL
# Out:
# Executing query with job ID: 2e78bfd0-4530-484d-bd4e-35904b503e7c
# Query executing: 0.83s
# Job ID 2e78bfd0-4530-484d-bd4e-35904b503e7c successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#          complain_detail
# 0      Dough undercooked
# 1      Drink was missing
# 2       Missing toppings
# 3    Order took too long
# 4        Pizza was burnt
# 5   Received wrong pizza
# 6  Rude staff at counter
# 7       Wrong pizza size

# %% [markdown]
# <a id="B.2."></a>
# ## <b>B.2. <span style='color:#0B2F9F'>Nilai Unik pada Lebih dari Satu Kolom</span></b>
#
# Perintah `DISTINCT` dapat diterapkan dilebih dari satu kolom. Jika diterapkan pada lebih dari satu kolom maka akan menghasilkan kombinasi unik antar baris pada kolom yang terpilih

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan siapa saja karyawan yang pernah menerima komplain dan jenis komplain apa saja yang pernah terjadi!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan siapa saja karyawan yang pernah menerima komplain dan
# -- jenis komplain apa saja yang pernah terjadi di DQPizza
# SELECT DISTINCT order_maker_id,complain_detail FROM dqlabs-project.dqpizza.transaction_order WHERE complain_detail IS NOT NULL
# Out:
# Executing query with job ID: bf131dad-443d-4a26-869e-667abdeed171
# Query executing: 0.45s
# Job ID bf131dad-443d-4a26-869e-667abdeed171 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#    order_maker_id    complain_detail
# 0       EMP000208  Dough undercooked
# 1       EMP000231  Dough undercooked
# 2       EMP000286  Dough undercooked
# 3       EMP000295  Dough undercooked
# 4       EMP000302  Dough undercooked
# ..            ...                ...
# 75      EMP000437   Wrong pizza size
# 76      EMP000560   Wrong pizza size
# 77      EMP000646   Wrong pizza size
# 78      EMP000665   Wrong pizza size
# 79      EMP000756   Wrong pizza size
#
# [80 rows x 2 columns]

# %% [markdown]
# <a id="C"></a>
# # <b>C. <span style='color:#E1B12D'><code>LIMIT</code></span></b>
#
# Tidak semua data ingin ditampilkan untuk proses <i>sampling</i>, sehingga perlu dikontrol dan melakukan pembatasan jumlah baris yang dikembalikan oleh sebuah query.
# Perintah `LIMIT <jumlah_data>` dalam SQL digunakan untuk membatasi data yang ingin ditampilkan. `LIMIT` diletakkan paling akhir dari sebuah query dengan perintah `SELECT`.
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-Limit.png" width="50%">
#
# docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/limit-optimization.html"><i>https://dev.mysql.com/doc/refman/8.4/en/limit-optimization.html</a></i>

# %% [markdown]
# <a id="C.1."></a>
# ## <b>C.1. <span style='color:#0B2F9F'>Membatasi Jumlah Baris (yang ditampilkan) di Semua Kolom pada Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua 5 data teratas pada tabel transaction_order!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua 5 data pada tabel transaction_order
# SELECT * FROM dqlabs-project.dqpizza.transaction_order LIMIT 5
# Out:
# Executing query with job ID: 8514d1f4-1b6a-47dc-9ddb-e6ad8677b5b5
# Query executing: 0.77s
# Job ID 8514d1f4-1b6a-47dc-9ddb-e6ad8677b5b5 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#     order_id customer_id order_maker_id  order_date order_time  \
# 0  TRX000026  CUST006333      EMP000208  01/01/2025   14:54:26
# 1  TRX000037  CUST003319      EMP000208  01/01/2025   16:56:09
# 2  TRX000057  CUST008422      EMP000208  01/01/2025   19:10:51
# 3  TRX000077  CUST001979      EMP000208  01/02/2025   12:22:46
# 4  TRX000087  CUST004837      EMP000208  01/02/2025   14:01:02
#
#   completion_time  is_complain complain_detail         created_date
# 0        15:23:02            0            None  2025-01-01 14:54:31
# 1        17:18:48            0            None  2025-01-01 16:56:14
# 2        19:30:38            0            None  2025-01-01 19:10:56
# 3        12:41:29            0            None  2025-01-02 12:22:51
# 4        14:29:46            0            None  2025-01-02 14:01:07

# %% [markdown]
# <a id="C.2."></a>
# ## <b>C.2. <span style='color:#0B2F9F'>Membatasi Jumlah Baris (yang ditampilkan) di Kolom Tertentu pada Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 7 data teratas untuk kolom order_id, customer_id, dan order_date pada tabel transaction_order!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan 7 data teratas saja untuk kolom order_id, customer_id dan order_date
# SELECT order_id, customer_id, order_date FROM dqlabs-project.dqpizza.transaction_order LIMIT 7
# Out:
# Executing query with job ID: 86e31d8a-7738-4290-ade7-84ce7dc0cb1f
# Query executing: 0.51s
# Job ID 86e31d8a-7738-4290-ade7-84ce7dc0cb1f successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#     order_id customer_id  order_date
# 0  TRX000026  CUST006333  01/01/2025
# 1  TRX000037  CUST003319  01/01/2025
# 2  TRX000057  CUST008422  01/01/2025
# 3  TRX000077  CUST001979  01/02/2025
# 4  TRX000087  CUST004837  01/02/2025
# 5  TRX000127  CUST008782  01/02/2025
# 6  TRX000133  CUST005109  01/02/2025

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 5 data saja pada kolom order_id, customer_id, order_date dan is_complain pada tabel transaction_order namun ubah penamaan is_complain pada output menjadi is_customer_complain agar lebih jelas</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan 5 data teratas saja untuk kolom order_id, customer_id, order_date dan is_complain pada tabel transaction_order
# -- namun ubah penamaan is_complain pada output menjadi is_customer_complain
# SELECT order_id, customer_id, order_date, is_complain as is_customer_complain FROM dqlabs-project.dqpizza.transaction_order LIMIT 5
# Out:
# Executing query with job ID: 1902fd02-d040-4c2b-a75e-bd4b1edc500d
# Query executing: 9.25s
# Job ID 1902fd02-d040-4c2b-a75e-bd4b1edc500d successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#     order_id customer_id  order_date  is_customer_complain
# 0  TRX000026  CUST006333  01/01/2025                     0
# 1  TRX000037  CUST003319  01/01/2025                     0
# 2  TRX000057  CUST008422  01/01/2025                     0
# 3  TRX000077  CUST001979  01/02/2025                     0
# 4  TRX000087  CUST004837  01/02/2025                     0

# %% [markdown]
# <a id="D"></a>
# # <b>D. <span style='color:#E1B12D'><code>ORDER BY</code></span></b>
#
# Perintah lain yang tak kalah penting yang membantu dalam menganalisis data untuk melihat data dalam urutan yang diinginkan adalah perintah `ORDER BY`. Perintah `ORDER BY` dalam SQL digunakan untuk mengurutkan hasil query berdasarkan satu atau lebih kolom. Cara pengurutan data dibagi menjadi dua cara yakni <b>Ascending</b> dan <b>Descending</b>
# <ul>
#     <li><b>Ascending</b> : Pengurutan secara naik (dari kecil ke besar) atau A-Z</li>
#     <li><b>Descending</b> : Pengurutan secara turun (dari besar ke kecil) atau Z-A</li>
# </ul>
#
# Untuk dapat menampilkan isi data secara terurut pada kolom tertentu pada sebuah tabel, eksekusi perintah
#
#
# <i>docs : <a href="https://dev.mysql.com/doc/refman/8.4/en/sorting-rows.html">https://dev.mysql.com/doc/refman/8.4/en/sorting-rows.html</a></i>

# %% [markdown]
# <a id="D.1."></a>
# ## <b>D.1. <span style='color:#0B2F9F'>Mengurutkan secara <i>Ascending</i></span></b>
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-OrderByASC.png" width="50%">

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel transaction_order namun urutkan berdasarkan kolom order_id secara ascending!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua data pada tabel transaction_order terurut berdasarkan kolom order_id secara ascending
# SELECT * FROM dqlabs-project.dqpizza.transaction_order ORDER BY order_id ASC
# Out:
# Executing query with job ID: faf27128-8aad-4bac-87b9-240499252806
# Query executing: 7.14s
# Job ID faf27128-8aad-4bac-87b9-240499252806 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#         order_id customer_id order_maker_id  order_date order_time  \
# 0      TRX000001  CUST007150      EMP000286  01/01/2025   11:38:36
# 1      TRX000002  CUST003319      EMP000646  01/01/2025   11:57:40
# 2      TRX000003  CUST001979      EMP000437  01/01/2025   12:12:28
# 3      TRX000004  CUST007254      EMP000302  01/01/2025   12:16:31
# 4      TRX000005  CUST004392      EMP000231  01/01/2025   12:21:30
# ...          ...         ...            ...         ...        ...
# 21345  TRX021346  CUST005584      EMP000560  12/31/2025   20:51:07
# 21346  TRX021347  CUST003549      EMP000302  12/31/2025   21:14:37
# 21347  TRX021348  CUST007931      EMP000437  12/31/2025   21:23:10
# 21348  TRX021349  CUST004212      EMP000231  12/31/2025   22:09:54
# 21349  TRX021350  CUST002637      EMP000665  12/31/2025   23:02:05
#
#       completion_time  is_complain   complain_detail         created_date
# 0            12:03:29            0              None  2025-01-01 11:38:41
# 1            12:09:32            0              None  2025-01-01 11:57:45
# 2            12:38:02            1  Missing toppings  2025-01-01 12:12:33
# 3            12:32:46            1  Missing toppings  2025-01-01 12:16:36
# 4            12:33:05            0              None  2025-01-01 12:21:35
# ...               ...          ...               ...                  ...
# 21345        21:20:56            0              None  2025-12-31 20:51:12
# 21346        21:30:28            0              None  2025-12-31 21:14:42
# 21347        21:47:34            0              None  2025-12-31 21:23:15
# 21348        22:29:02            0              None  2025-12-31 22:09:59
# 21349        23:18:55            0              None  2025-12-31 23:02:10
#
# [21350 rows x 9 columns]

# %% [markdown]
# <a id="D.2."></a>
# ## <b>D.2. <span style='color:#0B2F9F'>Mengurutkan secara <i>Descending</i></span></b>
#
# <img src="https://raw.githubusercontent.com/bachtiyarma/Material/main/Image/Materi-SQL/SQL-OrderByDESC.png" width="50%">

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel transaction_order namun urutkan berdasarkan kolom order_date secara descending!</b></i>

# %%
# %%bigquery --project {project_id} --verbose
#
# -- Tampilkan semua data pada tabel transaction_order terurut berdasarkan kolom order_date secara descending
# SELECT * FROM dqlabs-project.dqpizza.transaction_order ORDER BY order_date DESC
# Out:
# Executing query with job ID: 3db28f2f-f1ae-4581-8654-968fdca9223d
# Query executing: 0.53s
# Job ID 3db28f2f-f1ae-4581-8654-968fdca9223d successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |
#         order_id customer_id order_maker_id  order_date order_time  \
# 0      TRX021329  CUST004934      EMP000665  12/31/2025   18:52:10
# 1      TRX021332  CUST006821      EMP000286  12/31/2025   19:06:29
# 2      TRX021282  CUST007854      EMP000286  12/31/2025   12:09:59
# 3      TRX021343  CUST009740      EMP000208  12/31/2025   20:27:23
# 4      TRX021324  CUST002945      EMP000208  12/31/2025   18:36:06
# ...          ...         ...            ...         ...        ...
# 21345  TRX000010  CUST007931      EMP000437  01/01/2025   13:00:15
# 21346  TRX000006  CUST002637      EMP000437  01/01/2025   12:29:36
# 21347  TRX000057  CUST008422      EMP000208  01/01/2025   19:10:51
# 21348  TRX000037  CUST003319      EMP000208  01/01/2025   16:56:09
# 21349  TRX000032  CUST001704      EMP000756  01/01/2025   15:53:18
#
#       completion_time  is_complain      complain_detail         created_date
# 0            19:07:29            0                 None  2025-12-31 18:52:15
# 1            19:35:03            1  Order took too long  2025-12-31 19:06:34
# 2            12:24:40            0                 None  2025-12-31 12:10:04
# 3            20:46:24            0                 None  2025-12-31 20:27:28
# 4            18:51:40            0                 None  2025-12-31 18:36:11
# ...               ...          ...                  ...                  ...
# 21345        13:14:11            0                 None  2025-01-01 13:00:20
# 21346        12:51:58            0                 None  2025-01-01 12:29:41
# 21347        19:30:38            0                 None  2025-01-01 19:10:56
# 21348        17:18:48            0                 None  2025-01-01 16:56:14
# 21349        16:16:43            0                 None  2025-01-01 15:53:23
#
# [21350 rows x 9 columns]

# %% [markdown]
# <a id="D.3."></a>
# ## <b>D.3. <span style='color:#0B2F9F'>Kombinasi <i>Ascending</i> & <i>Descending</i> saat Mengurutkan Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan siapa saja karyawan yang pernah menerima komplain dan jenis komplain apa saja yang pernah terjadi, urutkan berdasarkan jenis komplainnya secara descending dan kode pegawai secara ascending!</b></i>

# %%
# %%bigquery df --project {project_id} --verbose
#
# -- Tampilkan siapa saja karyawan yang pernah menerima komplain dan jenis komplain apa saja yang pernah terjadi
# -- urutkan berdasarkan jenis komplainnya secara descending dan kode pegawai secara ascending
# SELECT order_maker_id,complain_detail FROM dqlabs-project.dqpizza.transaction_order WHERE complain_detail IS NOT NULL
# ORDER BY complain_detail DESC, order_maker_id ASC
# Out:
# Executing query with job ID: 7ee4b1cf-8be1-4898-9f21-480d73b749f4
# Query executing: 0.58s
# Job ID 7ee4b1cf-8be1-4898-9f21-480d73b749f4 successfully executed
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
display(df.head(5))
# Out:
#   order_maker_id   complain_detail
# 0      EMP000208  Wrong pizza size
# 1      EMP000208  Wrong pizza size
# 2      EMP000208  Wrong pizza size
# 3      EMP000208  Wrong pizza size
# 4      EMP000208  Wrong pizza size

# %% [markdown]
# Data Source : <i>https://mavenanalytics.io/challenges/maven-pizza-challenge</i> (dengan modifikasi)
#
#
# ---
#
# <br>
# <a href="https://www.linkedin.com/in/bachtiyarma/"><img src="https://img.shields.io/badge/-© 2025 Bachtiyar M. Arief-417DAC?style=for-the-badge&logoColor=white"/></a>
#
# <a href="https://dqlab.id/"><img src="https://dqlab.id/files/dqlab/cache/87e30118ebba5ec7d96f6ea8c9dcc10b_x_118_X_55.png" align="left" /></a>
