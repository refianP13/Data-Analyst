# %% [markdown]
# <a href="https://colab.research.google.com/github/refianP13/Data-Analyst/blob/main/Copy_of_%5BMENTOR_VER%5D_SESI_10_Pandas_dan_Manipulasi_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/sample_data/SuperStore.xlsx")
df.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         Product_Name Order_Date  Ship_Date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %%
df.head(10)
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# 5  CA-2017-115812    BH-11710        90032  FUR-FU-10001487   48.8600
# 6  CA-2017-115812    BH-11710        90032  OFF-AR-10002833    7.2800
# 7  CA-2017-115812    BH-11710        90032  TEC-PH-10002275  907.1520
# 8  CA-2017-115812    BH-11710        90032  OFF-BI-10003910   18.5040
# 9  CA-2017-115812    BH-11710        90032  OFF-AP-10002892  114.9000
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# ...

# %%
df.tail(10)
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID    Sales  \
# 9984  CA-2018-100251    DV-13465        11561  OFF-LA-10003766   31.500
# 9985  CA-2018-100251    DV-13465        11561  OFF-SU-10000898   55.600
# 9986  CA-2019-125794    ML-17410        90008  TEC-AC-10003399   36.240
# 9987  CA-2020-163629    RA-19885        30605  TEC-AC-10001539   79.990
# 9988  CA-2020-163629    RA-19885        30605  TEC-PH-10004006  206.100
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.248
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.960
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.576
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.600
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.160
#
#       Quantity  Discount   Profit         Category Sub-Category  \
# 9984        10       0.0  15.1200  Office Supplies       Labels
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   datetime64[ns]
#  12  Ship_Date       9994 non-null   datetime64[ns]
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Sales']
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
type(df['Sales'])
# Out:
# pandas.core.series.Series

# %%
df[['Sales']]
# Out:
#          Sales
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680
# ...        ...
# 9989   25.2480
# 9990   91.9600
# 9991  258.5760
# 9992   29.6000
# 9993  243.1600
#
# [9994 rows x 1 columns]

# %% [markdown]
# ## Mengganti type data Sales, Discount dan Profit dari Object ke Float

# %%
df['Sales'] = df['Sales'].str.replace(',', '.').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   object
#  7   Profit          9994 non-null   object
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   object
#  12  Ship_Date       9994 non-null   object
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
#  16  Country_Region  9994 non-null   object
# ...

# %%
df['Discount'] = df['Discount'].str.replace(',', '.').astype(float)
df['Profit'] = df['Profit'].str.replace(',', '.').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   object
#  12  Ship_Date       9994 non-null   object
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
#  16  Country_Region  9994 non-null   object
# ...

# %%
df.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         Product_Name  Order_Date   Ship_Date  \
# 0                  Bush Somerset Collection Bookcase   11/8/2019  11/11/2019
# ...

# %% [markdown]
# ## Mengganti type data Order_Date dan Ship_Date dari Object ke Date

# %%
contoh_df = pd.DataFrame({"year": [2015, 2016],
                   "month": [2, 3],
                   "day": [4, 5]})
contoh_df
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
contoh_df['date']= pd.to_datetime(contoh_df[['year', 'month', 'day']])
contoh_df
# Out:
#    year  month  day       date
# 0  2015      2    4 2015-02-04
# 1  2016      3    5 2016-03-05

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   datetime64[ns]
#  12  Ship_Date       9994 non-null   datetime64[ns]
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
# ...

# %% [markdown]
# ## Mengganti format nama kolom menjadi lowercase

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Postal_Code', 'Product_ID', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Category', 'Sub-Category',
#        'Product_Name', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_Name',
#        'Segment', 'Country/Region', 'City', 'State', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['order_id', 'customer_id', 'postal_code', 'product_id', 'sales',
#        'quantity', 'discount', 'profit', 'category', 'sub-category',
#        'product_name', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'country/region', 'city', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# ## Perbedaan Series dan DataFrame

# %%
# Series
customer_id = df['customer_id']
customer_id
# Out:
# 0       CG-12520
# 1       CG-12520
# 2       DV-13045
# 3       SO-20335
# 4       SO-20335
#           ...
# 9989    TB-21400
# 9990    DB-13060
# 9991    DB-13060
# 9992    DB-13060
# 9993    CC-12220
# Name: customer_id, Length: 9994, dtype: object

# %%
# DataFrame
customer_id_sales = df[['customer_id', 'sales']]
customer_id_sales
# Out:
#      customer_id     sales
# 0       CG-12520  261.9600
# 1       CG-12520  731.9400
# 2       DV-13045   14.6200
# 3       SO-20335  957.5775
# 4       SO-20335   22.3680
# ...          ...       ...
# 9989    TB-21400   25.2480
# 9990    DB-13060   91.9600
# 9991    DB-13060  258.5760
# 9992    DB-13060   29.6000
# 9993    CC-12220  243.1600
#
# [9994 rows x 2 columns]

# %% [markdown]
# ## Descriptive Analysis

# %%
df.describe()
# Out:
#         postal_code         sales     quantity     discount       profit  \
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.371023    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000
# std    32063.704510    623.245101     2.225110     0.206452   234.260108
#
#                           order_date                      ship_date
# count                           9994                           9994
# mean   2019-04-30 17:41:20.448268800  2019-05-04 16:42:15.921553152
# min              2017-01-03 00:00:00            2017-01-07 00:00:00
# ...

# %% [markdown]
# ## Data Visualisasi menggunakan Pandas

# %%
df['sales'].plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Slicing menggunakan .loc dan .iloc

# %%
#     [baris, kolom]
# .loc tidak berdasarkan index, tapi value aslinya
df.loc[:10, ['order_id', 'sales']]
# Out:
#           order_id      sales
# 0   CA-2019-152156   261.9600
# 1   CA-2019-152156   731.9400
# 2   CA-2019-138688    14.6200
# 3   US-2018-108966   957.5775
# 4   US-2018-108966    22.3680
# 5   CA-2017-115812    48.8600
# 6   CA-2017-115812     7.2800
# 7   CA-2017-115812   907.1520
# 8   CA-2017-115812    18.5040
# 9   CA-2017-115812   114.9000
# 10  CA-2017-115812  1706.1840

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'postal_code', 'product_id', 'sales',
#        'quantity', 'discount', 'profit', 'category', 'sub-category',
#        'product_name', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'country/region', 'city', 'state', 'region'],
#       dtype='object')

# %%
#     [baris, kolom]
# .iloc berdasarkan index, tapi value aslinya
df.iloc[:11, [0, 4]]
# Out:
#           order_id      sales
# 0   CA-2019-152156   261.9600
# 1   CA-2019-152156   731.9400
# 2   CA-2019-138688    14.6200
# 3   US-2018-108966   957.5775
# 4   US-2018-108966    22.3680
# 5   CA-2017-115812    48.8600
# 6   CA-2017-115812     7.2800
# 7   CA-2017-115812   907.1520
# 8   CA-2017-115812    18.5040
# 9   CA-2017-115812   114.9000
# 10  CA-2017-115812  1706.1840

# %% [markdown]
# ## Filtering

# %%
df.head()
# Out:
#          order_id customer_id  postal_code       product_id     sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    quantity  discount    profit         category sub-category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         product_name order_date  ship_date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %%
df[df['sales'] > df['sales'].mean()]
# SELECT * FROM df WHERE sales > AVG(sales)
# Out:
#             order_id customer_id  postal_code       product_id      sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798   261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454   731.9400
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577   957.5775
# 7     CA-2017-115812    BH-11710        90032  TEC-PH-10002275   907.1520
# 10    CA-2017-115812    BH-11710        90032  FUR-TA-10001539  1706.1840
# ...              ...         ...          ...              ...        ...
# 9973  US-2019-103674    AP-10720        90032  TEC-PH-10004080   271.9600
# 9976  US-2019-103674    AP-10720        90032  TEC-PH-10002496   249.5840
# 9979  US-2019-103674    AP-10720        90032  OFF-BI-10002026   437.4720
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645   258.5760
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684   243.1600
#
#       quantity  discount    profit         category sub-category  \
# ...

# %%
df['sales'] > df['sales'].mean()
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991     True
# 9992    False
# 9993     True
# Name: sales, Length: 9994, dtype: bool

# %%
df_sales_up_100_no_disk = df[df['sales'] > 100]
df_sales_up_100_no_disk = df_sales_up_100_no_disk[df_sales_up_100_no_disk['discount'] == 0]
df_sales_up_100_no_disk
# Out:
#             order_id customer_id  postal_code       product_id    sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798   261.96
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454   731.94
# 9     CA-2017-115812    BH-11710        90032  OFF-AP-10002892   114.90
# 16    CA-2017-105893    PK-19075        53711  OFF-ST-10004186   665.88
# 24    CA-2018-106320    EB-13870        84057  FUR-TA-10000577  1044.63
# ...              ...         ...          ...              ...      ...
# 9968  CA-2020-153871    RB-19435         7060  OFF-BI-10004600   735.98
# 9970  CA-2018-103772    MP-17470        30080  OFF-BI-10002867   119.56
# 9971  CA-2018-103772    MP-17470        30080  OFF-AR-10000538   140.75
# 9988  CA-2020-163629    RA-19885        30605  TEC-PH-10004006   206.10
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684   243.16
#
#       quantity  discount    profit         category sub-category  \
# ...

# %%
df_sales_disc = df[(df['sales']>df['sales'].mean()) & (df['discount']>0)]
# SELECT * FROM df WHERE sales > AVG(sales) AND discount > 0
df_sales_disc
# Out:
#             order_id customer_id  postal_code       product_id      sales  \
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577   957.5775
# 7     CA-2017-115812    BH-11710        90032  TEC-PH-10002275   907.1520
# 10    CA-2017-115812    BH-11710        90032  FUR-TA-10001539  1706.1840
# 11    CA-2017-115812    BH-11710        90032  TEC-PH-10002033   911.4240
# 13    CA-2019-161389    IM-15070        98103  OFF-BI-10003656   407.9760
# ...              ...         ...          ...              ...        ...
# 9962  CA-2018-168088    CM-12655        77041  FUR-BO-10004218   383.4656
# 9973  US-2019-103674    AP-10720        90032  TEC-PH-10004080   271.9600
# 9976  US-2019-103674    AP-10720        90032  TEC-PH-10002496   249.5840
# 9979  US-2019-103674    AP-10720        90032  OFF-BI-10002026   437.4720
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645   258.5760
#
#       quantity  discount    profit         category sub-category  \
# ...

# %%
furniture_sales = df[df['category'].isin(['Furniture', 'Technology', 'Office Supply'])]
furniture_sales
# Out:
#             order_id customer_id  postal_code       product_id     sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 5     CA-2017-115812    BH-11710        90032  FUR-FU-10001487   48.8600
# 7     CA-2017-115812    BH-11710        90032  TEC-PH-10002275  907.1520
# ...              ...         ...          ...              ...       ...
# 9987  CA-2020-163629    RA-19885        30605  TEC-AC-10001539   79.9900
# 9988  CA-2020-163629    RA-19885        30605  TEC-PH-10004006  206.1000
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.2480
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.9600
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.5760
#
#       quantity  discount    profit    category sub-category  \
# ...

# %% [markdown]
# ## Group By

# %%
group_cat_sub = df[['category', 'sub-category', 'sales']].groupby(['category', 'sub-category']).sum()
group_cat_sub
# Out:
#                                     sales
# category        sub-category
# Furniture       Bookcases     114879.9963
#                 Chairs        328449.1030
#                 Furnishings    91705.1640
#                 Tables        206965.5320
# Office Supplies Appliances    107532.1610
#                 Art            27118.7920
#                 Binders       203412.7330
#                 Envelopes      16476.4020
#                 Fasteners       3024.2800
#                 Labels         12486.3120
#                 Paper          78479.2060
#                 Storage       223843.6080
#                 Supplies       46673.5380
# Technology      Accessories   167380.3180
#                 Copiers       149528.0300
#                 Machines      189238.6310
#                 Phones        330007.0540

# %%
group_cat_sub.reset_index(inplace=True)
group_cat_sub
# Out:
#            category sub-category        sales
# 0         Furniture    Bookcases  114879.9963
# 1         Furniture       Chairs  328449.1030
# 2         Furniture  Furnishings   91705.1640
# 3         Furniture       Tables  206965.5320
# 4   Office Supplies   Appliances  107532.1610
# 5   Office Supplies          Art   27118.7920
# 6   Office Supplies      Binders  203412.7330
# 7   Office Supplies    Envelopes   16476.4020
# 8   Office Supplies    Fasteners    3024.2800
# 9   Office Supplies       Labels   12486.3120
# 10  Office Supplies        Paper   78479.2060
# 11  Office Supplies      Storage  223843.6080
# 12  Office Supplies     Supplies   46673.5380
# 13       Technology  Accessories  167380.3180
# 14       Technology      Copiers  149528.0300
# 15       Technology     Machines  189238.6310
# 16       Technology       Phones  330007.0540

# %% [markdown]
# ## Sort Values

# %%
df.sort_values('sales', ascending=False)
# Out:
#             order_id customer_id  postal_code       product_id      sales  \
# 2697  CA-2017-145317    SM-20320        32216  TEC-MA-10002412  22638.480
# 6826  CA-2019-118689    TC-20980        47905  TEC-CO-10004722  17499.950
# 8153  CA-2020-140151    RB-19360        98115  TEC-CO-10004722  13999.960
# 2623  CA-2020-127180    TA-21385        10024  TEC-CO-10004722  11199.968
# 4190  CA-2020-166709    HL-15040        19711  TEC-CO-10004722  10499.970
# ...              ...         ...          ...              ...        ...
# 2106  US-2017-152723    HG-14965        75150  OFF-BI-10003460      0.876
# 4711  CA-2017-112403    JO-15280        19120  OFF-BI-10003529      0.852
# 8658  CA-2019-168361    KB-16600        60623  OFF-BI-10003727      0.836
# 9292  CA-2020-124114    RS-19765        76706  OFF-BI-10004022      0.556
# 4101  US-2020-102288    ZC-21910        77095  OFF-AP-10002906      0.444
#
#       quantity  discount     profit         category sub-category  \
# ...

# %%
df.sort_values(['sales', 'sub-category'], ascending=False)
# Out:
#             order_id customer_id  postal_code       product_id      sales  \
# 2697  CA-2017-145317    SM-20320        32216  TEC-MA-10002412  22638.480
# 6826  CA-2019-118689    TC-20980        47905  TEC-CO-10004722  17499.950
# 8153  CA-2020-140151    RB-19360        98115  TEC-CO-10004722  13999.960
# 2623  CA-2020-127180    TA-21385        10024  TEC-CO-10004722  11199.968
# 4190  CA-2020-166709    HL-15040        19711  TEC-CO-10004722  10499.970
# ...              ...         ...          ...              ...        ...
# 2106  US-2017-152723    HG-14965        75150  OFF-BI-10003460      0.876
# 4711  CA-2017-112403    JO-15280        19120  OFF-BI-10003529      0.852
# 8658  CA-2019-168361    KB-16600        60623  OFF-BI-10003727      0.836
# 9292  CA-2020-124114    RS-19765        76706  OFF-BI-10004022      0.556
# 4101  US-2020-102288    ZC-21910        77095  OFF-AP-10002906      0.444
#
#       quantity  discount     profit         category sub-category  \
# ...

# %% [markdown]
# ## Value Counts

# %%
df['region'].value_counts()
# Out:
# region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df['region'].value_counts(normalize=True)
# Out:
# region
# West       0.320492
# East       0.284971
# Central    0.232439
# South      0.162097
# Name: proportion, dtype: float64

# %% [markdown]
# ## Pivot Table

# %%
df.head()
# Out:
#          order_id customer_id  postal_code       product_id     sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    quantity  discount    profit         category sub-category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         product_name order_date  ship_date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %%
pd.pivot_table(df, index='region', columns='category', values=['sales', 'quantity'], aggfunc='sum')
# Out:
#           quantity                                   sales                  \
# category Furniture Office Supplies Technology    Furniture Office Supplies
# region
# Central       1827            5409       1544  163797.1638      167026.415
# East          2214            6462       1942  208291.2040      205516.055
# South         1291            3800       1118  117298.6840      125651.313
# West          2696            7235       2335  252612.7435      220853.249
#
#
# category  Technology
# region
# Central   170416.312
# East      264973.981
# South     148771.908
# West      251991.832
